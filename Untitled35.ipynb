# %% [markdown]
# <a href="https://colab.research.google.com/github/samhoon000/Real-World-Drug-Surveillance/blob/main/Untitled35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url="https://api.fda.gov/drug/event.json?limit=100"
response=requests.get(url)
data=response.json()

# %%
import pandas as pd
df_uncleaned = pd.json_normalize(data['results'])

# %% [markdown]
# # ***Data Preprocessing***

# %%
df_uncleaned
# Out:
#    safetyreportid transmissiondateformat transmissiondate serious  \
# 0       5801206-7                    102         20090109       1
# 1        10003300                    102         20141002       1
# 2        10003301                    102         20141002       1
# 3        10003302                    102         20141002       2
# 4        10003304                    102         20141212       2
# ..            ...                    ...              ...     ...
# 95       10003396                    102         20151125       2
# 96       10003397                    102         20141212       1
# 97       10003398                    102         20141002       1
# 98       10003399                    102         20151125       2
# 99       10003400                    102         20151125       2
#
#    seriousnessdeath receivedateformat receivedate receiptdateformat  \
# 0                 1               102    20080707               102
# 1               NaN               102    20140306               102
# 2               NaN               102    20140228               102
# 3               NaN               102    20140312               102
# 4               NaN               102    20140312               102
# ..              ...               ...         ...               ...
# 95              NaN               102    20140312               102
# 96              NaN               102    20140312               102
# 97              NaN               102    20140312               102
# 98              NaN               102    20140312               102
# 99              NaN               102    20140312               102
#
#    receiptdate fulfillexpeditecriteria  ... sender.sendertype  \
# 0     20080625                       1  ...               NaN
# 1     20140306                       2  ...                 2
# 2     20140228                       2  ...                 2
# 3     20140312                       2  ...                 2
# 4     20140424                       2  ...                 2
# ..         ...                     ...  ...               ...
# 95    20150812                       2  ...                 2
# 96    20140418                       1  ...                 2
# 97    20140312                       1  ...                 2
# 98    20150812                       2  ...                 2
# 99    20150812                       2  ...                 2
#
#     receiver.receivertype receiver.receiverorganization seriousnessother  \
# 0                     NaN                           NaN              NaN
# 1                       6                           FDA              NaN
# 2                       6                           FDA                1
# 3                       6                           FDA              NaN
# 4                       6                           FDA              NaN
# ..                    ...                           ...              ...
# 95                      6                           FDA              NaN
# 96                      6                           FDA              NaN
# 97                      6                           FDA              NaN
# 98                      6                           FDA              NaN
# 99                      6                           FDA              NaN
#
#    occurcountry patient.patientagegroup seriousnesshospitalization  \
# 0           NaN                     NaN                        NaN
# 1           NaN                     NaN                        NaN
# 2           NaN                     NaN                        NaN
# 3            US                     NaN                        NaN
# 4            US                     NaN                        NaN
# ..          ...                     ...                        ...
# 95           US                       5                        NaN
# 96           IT                     NaN                          1
# 97           GB                     NaN                        NaN
# 98           US                       5                        NaN
# 99           US                       6                        NaN
#
#    patient.summary.narrativeincludeclinical  seriousnesslifethreatening  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# ..                                      ...                         ...
# 95                                      NaN                         NaN
# 96                                      NaN                         NaN
# 97                                      NaN                           1
# 98                                      NaN                         NaN
# 99                                      NaN                         NaN
#
#     patient.patientweight
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 95                    NaN
# 96                    NaN
# 97                    NaN
# 98                    NaN
# 99                    NaN
#
# [100 rows x 39 columns]

# %%
df_uncleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 39 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   safetyreportid                               100 non-null    object
#  1   transmissiondateformat                       100 non-null    object
#  2   transmissiondate                             100 non-null    object
#  3   serious                                      100 non-null    object
#  4   seriousnessdeath                             4 non-null      object
#  5   receivedateformat                            100 non-null    object
#  6   receivedate                                  100 non-null    object
#  7   receiptdateformat                            100 non-null    object
#  8   receiptdate                                  100 non-null    object
#  9   fulfillexpeditecriteria                      100 non-null    object
#  10  companynumb                                  100 non-null    object
#  11  receiver                                     0 non-null      float64
#  12  primarysource.reportercountry                100 non-null    object
#  13  primarysource.qualification                  99 non-null     object
#  14  sender.senderorganization                    100 non-null    object
#  15  patient.patientonsetage                      89 non-null     object
#  16  patient.patientonsetageunit                  89 non-null     object
#  17  patient.patientsex                           100 non-null    object
#  18  patient.patientdeath.patientdeathdateformat  0 non-null      float64
#  19  patient.patientdeath.patientdeathdate        0 non-null      float64
#  20  patient.reaction                             100 non-null    object
#  21  patient.drug                                 100 non-null    object
#  22  safetyreportversion                          99 non-null     object
#  23  primarysourcecountry                         99 non-null     object
#  24  reporttype                                   99 non-null     object
#  25  seriousnessdisabling                         2 non-null      object
#  26  duplicate                                    99 non-null     object
#  27  reportduplicate.duplicatesource              99 non-null     object
#  28  reportduplicate.duplicatenumb                99 non-null     object
#  29  sender.sendertype                            99 non-null     object
#  30  receiver.receivertype                        99 non-null     object
#  31  receiver.receiverorganization                99 non-null     object
#  32  seriousnessother                             14 non-null     object
#  33  occurcountry                                 97 non-null     object
#  34  patient.patientagegroup                      59 non-null     object
#  35  seriousnesshospitalization                   21 non-null     object
#  36  patient.summary.narrativeincludeclinical     18 non-null     object
#  37  seriousnesslifethreatening                   3 non-null      object
#  38  patient.patientweight                        11 non-null     object
# dtypes: float64(3), object(36)
# memory usage: 30.6+ KB

# %%
df=df_uncleaned[['serious','patient.patientonsetage','patient.reaction','patient.drug','occurcountry']]

# %%
df.head()
# Out:
#   serious patient.patientonsetage  \
# 0       1                      26
# 1       1                      77
# 2       1                     NaN
# 3       2                     NaN
# 4       2                     NaN
#
#                                     patient.reaction  \
# 0  [{'reactionmeddrapt': 'DRUG ADMINISTRATION ERR...
# 1  [{'reactionmeddraversionpt': '17.0', 'reaction...
# 2  [{'reactionmeddraversionpt': '17.0', 'reaction...
# 3  [{'reactionmeddraversionpt': '17.0', 'reaction...
# 4  [{'reactionmeddraversionpt': '17.0', 'reaction...
#
#                                         patient.drug occurcountry
# 0  [{'drugcharacterization': '1', 'medicinalprodu...          NaN
# 1  [{'drugcharacterization': '1', 'medicinalprodu...          NaN
# 2  [{'drugcharacterization': '1', 'medicinalprodu...          NaN
# 3  [{'drugcharacterization': '1', 'medicinalprodu...           US
# 4  [{'drugcharacterization': '1', 'medicinalprodu...           US

# %%
df['patient.reaction'].iloc[1]
# Out:
# [{'reactionmeddraversionpt': '17.0', 'reactionmeddrapt': 'Vomiting'},
#  {'reactionmeddraversionpt': '17.0', 'reactionmeddrapt': 'Diarrhoea'},
#  {'reactionmeddraversionpt': '17.0', 'reactionmeddrapt': 'Arthralgia'},
#  {'reactionmeddraversionpt': '17.0', 'reactionmeddrapt': 'Headache'}]

# %%
df['patient.drug'].iloc[1]
# Out:
# [{'drugcharacterization': '1',
#   'medicinalproduct': 'BONIVA',
#   'drugbatchnumb': 'H6200HO3',
#   'drugauthorizationnumb': '021858',
#   'drugstructuredosagenumb': '3',
#   'drugstructuredosageunit': '003',
#   'drugdosagetext': '3 MG, 1 IN 3 M, INTRAVENOUS (NOT OTHERWISE SPECIFIED)',
#   'drugadministrationroute': '042',
#   'drugindication': 'OSTEOPOROSIS',
#   'drugstartdateformat': '102',
#   'drugstartdate': '20130913'}]

# %%
# Convert patient.reaction into a list with all the reactionmeddrapt
df['reactions_clean'] = df['patient.reaction'].apply(
    lambda lst: [x['reactionmeddrapt'] for x in lst] if isinstance(lst, list) else []
)
# Out:
# /tmp/ipykernel_3179/3136934680.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reactions_clean'] = df['patient.reaction'].apply(

# %%
df.head()
# Out:
#   serious patient.patientonsetage  \
# 0       1                      26
# 1       1                      77
# 2       1                     NaN
# 3       2                     NaN
# 4       2                     NaN
#
#                                     patient.reaction  \
# 0  [{'reactionmeddrapt': 'DRUG ADMINISTRATION ERR...
# 1  [{'reactionmeddraversionpt': '17.0', 'reaction...
# 2  [{'reactionmeddraversionpt': '17.0', 'reaction...
# 3  [{'reactionmeddraversionpt': '17.0', 'reaction...
# 4  [{'reactionmeddraversionpt': '17.0', 'reaction...
#
#                                         patient.drug occurcountry  \
# 0  [{'drugcharacterization': '1', 'medicinalprodu...          NaN
# 1  [{'drugcharacterization': '1', 'medicinalprodu...          NaN
# 2  [{'drugcharacterization': '1', 'medicinalprodu...          NaN
# 3  [{'drugcharacterization': '1', 'medicinalprodu...           US
# 4  [{'drugcharacterization': '1', 'medicinalprodu...           US
#
#                                reactions_clean
# 0        [DRUG ADMINISTRATION ERROR, OVERDOSE]
# 1  [Vomiting, Diarrhoea, Arthralgia, Headache]
# 2                [Dyspepsia, Renal impairment]
# 3                           [Drug ineffective]
# 4                      [Drug hypersensitivity]

# %%
df['drug_name']=df['patient.drug'].apply(lambda lst: [x['medicinalproduct'] for x in lst] if isinstance(lst,list) else [])
# Out:
# /tmp/ipykernel_3179/1758806435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['drug_name']=df['patient.drug'].apply(lambda lst: [x['medicinalproduct'] for x in lst] if isinstance(lst,list) else [])

# %%
df=df.drop(columns=['patient.reaction','patient.drug'])

# %%
df.head()
# Out:
#   serious patient.patientonsetage occurcountry  \
# 0       1                      26          NaN
# 1       1                      77          NaN
# 2       1                     NaN          NaN
# 3       2                     NaN           US
# 4       2                     NaN           US
#
#                                reactions_clean  \
# 0        [DRUG ADMINISTRATION ERROR, OVERDOSE]
# 1  [Vomiting, Diarrhoea, Arthralgia, Headache]
# 2                [Dyspepsia, Renal impairment]
# 3                           [Drug ineffective]
# 4                      [Drug hypersensitivity]
#
#                                            drug_name
# 0                                    [DURAGESIC-100]
# 1                                           [BONIVA]
# 2                                        [IBUPROFEN]
# 3                                           [LYRICA]
# 4  [DOXYCYCLINE HYCLATE, TRAMADOL HYDROCHLORIDE, ...

# %%
df=df.explode('reactions_clean')
df=df.explode('drug_name')

# %%
df.head()
# Out:
#   serious patient.patientonsetage occurcountry            reactions_clean  \
# 0       1                      26          NaN  DRUG ADMINISTRATION ERROR
# 0       1                      26          NaN                   OVERDOSE
# 1       1                      77          NaN                   Vomiting
# 1       1                      77          NaN                  Diarrhoea
# 1       1                      77          NaN                 Arthralgia
#
#        drug_name
# 0  DURAGESIC-100
# 0  DURAGESIC-100
# 1         BONIVA
# 1         BONIVA
# 1         BONIVA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 875 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   serious                  875 non-null    object
#  1   patient.patientonsetage  799 non-null    object
#  2   occurcountry             867 non-null    object
#  3   reactions_clean          875 non-null    object
#  4   drug_name                875 non-null    object
# dtypes: object(5)
# memory usage: 41.0+ KB

# %%
df['serious']=pd.to_numeric(df['serious'],errors='coerce')

# %%
df['patient.patientonsetage']=pd.to_numeric(df['patient.patientonsetage'],errors='coerce')

# %%
df.rename(columns={'reactions_clean':'reactions','patient.patientonsetage':'patient_age'},inplace=True)

# %%
df=df.dropna()

# %%
df.head()
# Out:
#    serious  patient_age occurcountry              reactions  \
# 5        2         48.0           US  Drug hypersensitivity
# 5        2         48.0           US  Drug hypersensitivity
# 5        2         48.0           US  Drug hypersensitivity
# 5        2         48.0           US  Drug hypersensitivity
# 5        2         48.0           US  Drug hypersensitivity
#
#              drug_name
# 5              LIPITOR
# 5           LISINOPRIL
# 5   LOSARTAN POTASSIUM
# 5  METOPROLOL TARTRATE
# 5          MINOCYCLINE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 793 entries, 5 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   serious       793 non-null    int64
#  1   patient_age   793 non-null    float64
#  2   occurcountry  793 non-null    object
#  3   reactions     793 non-null    object
#  4   drug_name     793 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 37.2+ KB

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### 1.Top 10 most common reactions

# %%
df['reactions'].value_counts().head(10)
# Out:
# reactions
# Diarrhoea                       60
# Pyrexia                         46
# Abdominal pain                  44
# Blood creatinine increased      44
# C-reactive protein increased    44
# Asthenia                        28
# Pleural effusion                22
# Dysuria                         22
# Weight decreased                22
# Headache                        17
# Name: count, dtype: int64
