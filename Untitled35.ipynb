# %% [markdown]
# <a href="https://colab.research.google.com/github/samhoon000/Real-World-Drug-Surveillance/blob/main/Untitled35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd

with open('drug-event-0001-of-0028.json') as f:
    data = json.load(f)

df_raw = pd.json_normalize(data['results'])

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 40 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   safetyreportversion                       12000 non-null  object
#  1   safetyreportid                            12000 non-null  object
#  2   primarysourcecountry                      11997 non-null  object
#  3   transmissiondateformat                    12000 non-null  object
#  4   transmissiondate                          12000 non-null  object
#  5   reporttype                                11997 non-null  object
#  6   serious                                   12000 non-null  object
#  7   seriousnessdeath                          11548 non-null  object
#  8   seriousnesslifethreatening                11516 non-null  object
#  9   seriousnesshospitalization                11665 non-null  object
#  10  seriousnessdisabling                      11503 non-null  object
#  11  seriousnesscongenitalanomali              11499 non-null  object
#  12  seriousnessother                          11731 non-null  object
#  13  receivedateformat                         12000 non-null  object
#  14  receivedate                               12000 non-null  object
#  15  receiptdateformat                         12000 non-null  object
#  16  receiptdate                               12000 non-null  object
#  17  fulfillexpeditecriteria                   12000 non-null  object
#  18  authoritynumb                             1553 non-null   object
#  19  primarysource.reportercountry             12000 non-null  object
#  20  primarysource.qualification               11895 non-null  object
#  21  sender.sendertype                         12000 non-null  object
#  22  sender.senderorganization                 12000 non-null  object
#  23  receiver.receivertype                     12000 non-null  object
#  24  receiver.receiverorganization             12000 non-null  object
#  25  patient.patientonsetage                   6970 non-null   object
#  26  patient.patientonsetageunit               6971 non-null   object
#  27  patient.patientsex                        9769 non-null   object
#  28  patient.reaction                          12000 non-null  object
#  29  patient.drug                              12000 non-null  object
#  30  patient.patientweight                     1906 non-null   object
#  31  patient.summary.narrativeincludeclinical  4636 non-null   object
#  32  occurcountry                              11392 non-null  object
#  33  companynumb                               10444 non-null  object
#  34  patient.patientagegroup                   3323 non-null   object
#  35  primarysource.literaturereference         1688 non-null   object
#  36  duplicate                                 2288 non-null   object
#  37  reportduplicate.duplicatesource           1642 non-null   object
#  38  reportduplicate.duplicatenumb             1656 non-null   object
#  39  reportduplicate                           630 non-null    object
# dtypes: object(40)
# memory usage: 3.7+ MB

# %%
df_raw['patient.reaction'].head()
# Out:
# 0    [{'reactionmeddraversionpt': '28.0', 'reaction...
# 1    [{'reactionmeddraversionpt': '28.0', 'reaction...
# 2    [{'reactionmeddraversionpt': '28.0', 'reaction...
# 3    [{'reactionmeddraversionpt': '27.1', 'reaction...
# 4    [{'reactionmeddraversionpt': '27.1', 'reaction...
# Name: patient.reaction, dtype: object

# %%
df_raw.to_csv("final_data2.csv")

# %%
def clean_data_better(df_uncleaned):
    import pandas as pd

    records = []

    for _, row in df_uncleaned.iterrows():

        report_id = row['safetyreportid']
        serious = row['serious']
        age = row['patient.patientonsetage']
        country = row['occurcountry']

        drugs = row['patient.drug']
        reactions = row['patient.reaction']

        # Extract drug names
        drug_list = []
        if isinstance(drugs, list):
            for d in drugs:
                name = d.get('medicinalproduct')
                if name:
                    drug_list.append(name)

        # Extract reactions
        reaction_list = []
        if isinstance(reactions, list):
            for r in reactions:
                name = r.get('reactionmeddrapt')
                if name:
                    reaction_list.append(name)

        # Skip empty
        if not drug_list or not reaction_list:
            continue

        # Remove duplicates inside a report
        drug_list = list(set(drug_list))
        reaction_list = list(set(reaction_list))

        # Create pairs (controlled)
        for drug in drug_list:
            for reaction in reaction_list:
                records.append({
                    'report_id': report_id,
                    'drug_name': drug,
                    'reactions': reaction,
                    'patient_age': age,
                    'serious': serious,
                    'occurcountry': country
                })

    df = pd.DataFrame(records)

    # Convert types
    df['serious'] = pd.to_numeric(df['serious'], errors='coerce')
    df['patient_age'] = pd.to_numeric(df['patient_age'], errors='coerce')

    # Drop missing
    df = df.dropna(subset=['drug_name', 'reactions'])

    df = df.reset_index(drop=True)

    return df

# %%
df=clean_data_better(df_raw)

# %%
df.head()
# Out:
#   report_id    drug_name                    reactions  patient_age  serious  \
# 0  25145749       RINVOQ             Cardiac disorder         59.0        2
# 1  25141489    IBUPROFEN  Thoracic vertebral fracture         67.0        1
# 2  25141489    IBUPROFEN                      Seizure         67.0        1
# 3  25141489  AMOXICILLIN  Thoracic vertebral fracture         67.0        1
# 4  25141489  AMOXICILLIN                      Seizure         67.0        1
#
#   occurcountry
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156285 entries, 0 to 156284
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   report_id     156285 non-null  object
#  1   drug_name     156285 non-null  object
#  2   reactions     156285 non-null  object
#  3   patient_age   116010 non-null  float64
#  4   serious       156285 non-null  int64
#  5   occurcountry  150134 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 7.2+ MB
